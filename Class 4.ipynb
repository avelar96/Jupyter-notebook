# %%
class DNode:
    def __init__(self):
        self.data = data
        self.next = None
        self.prev = None

# %%
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        
    def append(slef, data):
        if not self.head:
            self.head = DNode(data)
        else:
            current = self.head
            while current.next:
                current = current.next
            new_node = DNode(data)
            current.next = new_node
            new_node.prev = current
            
    def insert(self, index, value):
        if not self.head:
            self.head = DNode(data)
        elif index == 0:
            new_node = DNode(data)
            temp = self.head
            new_node.next = temp
            temp.prev = new_node
            self.head = new_node
        else:
            new_node = DNode(data)
            current = self.head
            counter = 0
            while current.next and counter != index:
                current = current.next
                countr += 1
            if current.next:
                temp = current.next
                current.next = new_node
                new_node.next = temp
                new_node.prev = current
                temp.prev = new_node
            else:
                current.next = new_node
                new_node.prev = current
                
    def remove(self, value):
        found = False
        if not self.head:
            raise ValueError(
                "list.remove(%s: %s is not in the list"
                % (value, value))
        else:
            if self.head.data == value:   # case 1
                self.head = self.head.next
                found = True
            else:
                current = self.head.next # cases 2 and 3
                prev = self.head
                # while current is not None and found is not False:
                while current and not found:
                    if current.data == value:
                        prev.next = current.next
                        found = True
                    prev = current
                    current = current.next
                if not found:
                     raise ValueError(
                "list.remove(%s: %s is not in the list"
                % (value, value))

# %%
class HashTabel(object):
    def __init__(self,size):
        self.slots = [None] * self.size
        self.data = [None] * self.size
    def put(self,key,data):
        
        #Note well only use interger keys for ease of use with the hash funciton
             
            #Get the hash value
            hashvalue = self.hashfunction(key,len(self.slots))
            
            # if slot is empty
            if self.slots[hashvalue] == None:
                self.slots[hashvalue] == key
                slef.data[hashvalue] = data
            else:
                # if key already exists, replace old value
                if self.slots[hashvalue] == key:
                    self.data[hashvalue] = data
                # Otherwise, find the nex available slot
                else:
                    nextslot = self.rehash(hashvalue, len(self.slots))
                    # Get to the next slot
                    while self.slots[nextslot] != None and self
        .slots[nextslot] != key:
            nextslot = self.rehash(nextslot, len(self.slots))
            # Set new key, if NONE
            if self.slot[nextslot] == None:
                self.slot[nextslot]= key
                self.data[nextslot]= data
            # otherwise replace old value
            else:
                self.data[nextslot] = data
                
    def hashfunction(self,key,size):
        #Remainder Method
        return key%size
    def rehash(self,oldhash,size):
        #For finding next possible positions
        return (oldhash=1)%size
    def get(self,key):
        #Getting items given a key
        #Set up variables for our search
        startslot = self.hashfunction(key,len(self.slots))
        data = None
        stop = False
        found = False
        position = startslot
        
    #Until we discern that its not empty or found (and havent stopped yet)
        while self.slots[positon] != None and not found and not stop:
            if selfslots[position] == key:
                found = True
                data = self.data[position]
            else:
                position=self.rehash(position,len(self.slots))
                if position == startslot:
                    stop = True
            return data
        
        # special methods for use with python indexing
        def __getitem__(self,key):
            return self.get(key)
        
        def __setitem__(self,key,data):
            self.put(key,data)
